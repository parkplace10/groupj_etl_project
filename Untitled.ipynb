# %%
import pandas as pd

# %%
csv_file = "W15_projections.csv"
four44_df = pd.read_csv(csv_file)

# Applying Fanduel uniform scoring system to Fantasy Sharks raw predictions and creating a new column with the results
four44_df['Site 2'] = four44_df['Pass Yds'] * .04 + four44_df['Rush Yds'] * .1 + four44_df['Rec Yds'] * .1 + \
four44_df['Pass TD'] * 4 + four44_df['Rush TD'] * 6 + four44_df['Rec TD'] * 6 + four44_df['Rec'] * .5 + four44_df['INT'] * -1 \
+ four44_df['Fum'] * -2 

#dropping unneeded columns
four44_df = four44_df.drop([
 'PID',
 'Pos',
 'Team',
 'Opp',
 'aFPA',
 'aFPA Rk',
 'FFPts',
 'Comp',
 'Pass Att',
 'Pass Yds',
 'Pass TD',
 'INT',
 'Rush Att',
 'Rush Yds',
 'Rush TD',
 'Rec',
 'Rec Yds',
 'Rec TD',
 'Pa1D',
 'Ru1D',
 'Rec1D',
 'Fum',
 'XP',
 'FG',
 'Grade'], axis=1)

four44_df.rename(columns = {"Player": "Name"}, inplace = True)

four44_df
four44_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 4 columns):
# Season    361 non-null int64
# Week      361 non-null int64
# Name      361 non-null object
# Site 2    361 non-null float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 11.4+ KB

# %%
list(four44_df)
# Out:
# ['Season',
#  'Week',
#  'PID',
#  'Player',
#  'Pos',
#  'Team',
#  'Opp',
#  'aFPA',
#  'aFPA Rk',
#  'FFPts',
#  'Comp',
#  'Pass Att',
#  'Pass Yds',
#  'Pass TD',
#  'INT',
#  'Rush Att',
#  'Rush Yds',
#  'Rush TD',
#  'Rec',
#  'Rec Yds',
#  'Rec TD',
#  'Pa1D',
#  'Ru1D',
#  'Rec1D',
#  'Fum',
#  'XP',
#  'FG',
#  'Grade']

# %%
csv_file = "fantasysharks-W15Projections.csv"
sharks_df = pd.read_csv(csv_file)

# Splitting the name into 2 seperate columns
sharks_df[['Last Name','First Name']] = sharks_df['Name'].str.split(', ',expand=True)

# Recombine names into one column in the order of First Last
sharks_df['Name'] = sharks_df['First Name'].str.cat(sharks_df['Last Name'],sep=" ")

# Applying Fanduel uniform scoring system to Fantasy Sharks raw predictions and creating a new column with the results
sharks_df['Fantasy Sharks'] = sharks_df['Yards'] * .04 + sharks_df['Yards.1'] * .1 + sharks_df['Yards.2'] * .1 + \
sharks_df['TD'] * 4 + sharks_df['TD.1'] * 6 + sharks_df['TD.2'] * 6 + sharks_df['Rec'] * .5 + sharks_df['Int'] * -1 

sharks_df = sharks_df.drop(['ID', 'Rank', 'First Name', 'Last Name', 'Comp', 'Yards', 'TD', 'TD.1', 
'TD.2', 'Int', 'Att', 'Yards.1', 'Yards.2', 'Rec', 'Fantasy Points'], axis=1)
sharks_df.head()
# Out:
#   Pos             Name Team  Opp  Fantasy Sharks
# 0  RB      Todd Gurley  LAR  PHI           24.73
# 1  QB  Patrick Mahomes  KCC  LAC           24.64
# 2  QB       Drew Brees  NOS  CAR           22.96
# 3  QB    Philip Rivers  LAC  KCC           21.72
# 4  QB     Kirk Cousins  MIN  MIA           21.42

# %%
combined_df = sharks_df.merge(four44_df, on=['Name'], sort=False)

# 282    2018    15      Cameron Batson  WR  TEN  NYG            0.51    1.61
# 283    2018    15       Tyler Conklin  TE  MIN  MIA            0.01    0.79
# 284    2018    15       Durham Smythe  TE  MIA  MIN            0.17    0.63
# 285    2018    15      Dalton Schultz  TE  DAL  IND            0.57    2.14
# 286    2018    15     Bruce Ellington  WR  DET  BUF            0.00    0.16
# 287    2018    15      DeAndre Carter  WR  HOU  NYJ            0.64    4.76
# 288    2018    15           Khari Lee  TE  BUF  DET            0.21    0.58
# 289    2018    15       Michael Floyd  WR  WAS  JAC            0.58    1.37
# 290    2018    15       Robert Tonyan  TE  GBP  CHI            0.73    0.51
# 291    2018    15         Austin Carr  WR  NOS  CAR            0.00    1.87
# 292    2018    15       Kalen Ballage  RB  MIA  MIN            0.55    0.78
# 293    2018    15     Darrel Williams  RB  KCC  LAC            0.57    5.03
# 294    2018    15          Auden Tate  WR  CIN  OAK            0.34    1.71
# 295    2018    15        Eric Saubert  TE  ATL  ARI            0.28    0.43
# 296    2018    15       Charone Peake  WR  NYJ  HOU            0.27    1.23
# 297    2018    15           Cody Core  WR  CIN  OAK            0.70    2.87
# 298    2018    15            C.J. Ham  RB  MIN  MIA            0.59    0.52
# 299    2018    15      Chris Manhertz  TE  CAR  NOS            0.30    1.45
# 300    2018    15         Matt Lengel  TE  CIN  OAK            0.80    1.60
# 301    2018    15        Justin Davis  RB  LAR  PHI            0.00    2.38
# 302    2018    15          Brian Hill  RB  ATL  ARI            0.51    0.38
#
# [303 rows x 8 columns]

# %%
url = "http://fantasy.nfl.com/research/projections#researchProjections=researchProjections%2C%2Fresearch%2Fprojections%253Foffset%253D{i}%2526position%253DO%2526sort%253DprojectedPts%2526statCategory%253DprojectedStats%2526statSeason%253D2018%2526statType%253DweekProjectedStats%2526statWeek%253D16%2Creplace"
nfl = pd.read_html(url)
# nfl_df = pd.DataFrame(nfl)
# nfl_df
# nfl

# nfl_df = pd.DataFrame(nfl.row.str.split(' ',1).tolist())
nfl_df['Name'] = df['First Name'].str.cat(df['Last Name'],sep=" ")
nfl_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-04bdfdf4d127> in <module>()
#       5 # nfl
#       6
# ----> 7 nfl_df = pd.DataFrame(nfl.row.str.split(' ',1).tolist())
#       8 nfl_df['Name'] = df['First Name'].str.cat(df['Last Name'],sep=" ")
#       9 nfl_df
#
# AttributeError: 'list' object has no attribute 'row'

# %%
#researchProjections=researchProjections%2C%2Fresearch%2Fprojections%253Foffset%253D1%2526position%253DO%2526sort%253DprojectedPts%2526statCategory%253DprojectedStats%2526statSeason%253D2018%2526statType%253DweekProjectedStats%2526statWeek%253D16%2Creplace
#researchProjections=researchProjections%2C%2Fresearch%2Fprojections%253Foffset%253D26%2526position%253DO%2526sort%253DprojectedPts%2526statCategory%253DprojectedStats%2526statSeason%253D2018%2526statType%253DweekProjectedStats%2526statWeek%253D16%2Creplace    
#researchProjections=researchProjections%2C%2Fresearch%2Fprojections%253Foffset%253D51%2526position%253DO%2526sort%253DprojectedPts%2526statCategory%253DprojectedStats%2526statSeason%253D2018%2526statType%253DweekProjectedStats%2526statWeek%253D16%2Creplace
